# %% [markdown]
# # File Operations
#
# Use the open() function to read(r), append (a), or write (w) to a file. Opening a file returns a file handle, not the actual data in the file. After opening the file you can read or write to it. When you are finished with the file, ensure it is closed. Failing to close a file may lead to memory issues, inaccessible files, and possibly data loss.

# %%
dir(glob)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dir(glob)
#
# NameError: name 'glob' is not defined

# %%
# use the os module to access operating system information such as the current working directory (getcwd())
import os

# Create (or overwrite) a file
# If no path is specified, the file will be created in the current working directory

# If the file exists, opening with the "w" parameter will overwrite a file of the same name
#   if present in the same folder. To append instead of overwriting, use the "a" mode.
f = open("demofile.txt", "w")

f.write("This is the first line of the file.\n")

# Be sure to close your file. Failure to do so will cause problems.
f.close()

# Get the current directory
print(os.getcwd())
# Out:
# /home/gjbott/Dropbox/research/github/gregbott/Python_For_Business_Students

# %%
# List the contents of the file (MAC and Linux)
# %cat demofile.txt
# Out:
# This is the first line of the file.

# %% [markdown]
# ## Using the With statement for opening files
# One advantage to using the With statement is that files you open using this method are automatically closed.

# %%
# Append the file
with open("demofile.txt", "a") as f:
    f.write("This is the second line.\n")

    # No need to explicitly close the file. Close() is automatically called.

# %%
# %cat demofile.txt

# %% [markdown]
# ## Using pathlib
# Handling files and folders programatically can be really difficult. You may need to locate and work with all files that have a particular extension, process folders recursively, identify the parent folder of a file or folder, and so on. One of the most powerful modules for file and folder management is pathlib.
#
# As the name implies, pathlib creates paths. To do so, it uses the Path class (note the uppercase P).

# %% [markdown]
# ### Get Named Folders

# %%
import pathlib
my_path = pathlib.Path.cwd()
print(my_path.name)
# Out:
# Python_For_Business_Students

# %% [markdown]
# The pathlib module provides an easy way to locate the user's home folder.

# %%
# Get the home folder for the current user
home_path = pathlib.Path.home()
print(home_path)
# Out:
# /home/gjbott

# %% [markdown]
# Finding all files of a particular type is accomplished by using Pathlib and the glob (global) module.

# %%
def show_tree(directory):
    print(f'+ {directory}')
    
    # Limited to Python notebooks
    for path in sorted(directory.rglob('*.ipynb')):
        depth = len(path.relative_to(directory).parts)
        indent = '    ' * depth
        print(f'{'  '} + {path.relative_to(directory).parts}')

# %%
show_tree(pathlib.Path.home())
# Out:
# + /home/gjbott
#    + ('.ipynb_checkpoints', 'Untitled-checkpoint.ipynb')
#    + ('.ipynb_checkpoints', 'Untitled1-checkpoint.ipynb')
#    + ('.ipynb_checkpoints', 'birthday_attack-checkpoint.ipynb')
#    + ('.vscode', 'extensions', 'ms-python.python-2023.20.0', 'pythonFiles', 'Notebooks intro.ipynb')
#    + ('Documents', '.ipynb_checkpoints', 'mis_ml-checkpoint.ipynb')
#    + ('Documents', 'mis_ml.ipynb')
#    + ('Downloads', 'Untitled.ipynb')
#    + ('Downloads', 'b_Using Jupyter Lab.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'service', 'external', 'zInactive', 'SIGSEC', 'SIGSEC election results.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'service', 'students', 'Audrey Kim', 'Audrey shared', '2022', '4262022_jsonToSQL.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'service', 'students', 'Audrey Kim', 'Audrey shared', '2022', 'EM_data_loader.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'service', 'university service', 'Cyber Camp', '2022 Cyber Camp', 'Registration', 'Cyber Applicant processing.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_student_resources', 'notebooks', 'Core Python-Varibles-Iteration-Conditionals-Copy1.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_student_resources', 'notebooks', 'a_Conda Environments.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_student_resources', 'notebooks', 'b_Using Jupyter Lab.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'Keys', 'KEY_KJV_password_generator.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'a_Conda Environments-notes.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M01 - Basics', '.ipynb_checkpoints', 'M1-A2 Hello World-checkpoint.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M01 - Basics', '.ipynb_checkpoints', 'M1-A3 Variables, Expressions, and Types (A)-checkpoint.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M01 - Basics', '.ipynb_checkpoints', 'M1-A4 Print and Input-checkpoint.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M01 - Basics', 'Basics', 'M1-A1 markdown exercise.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M01 - Basics', 'Basics', 'M1-A2 Hello World.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M01 - Basics', 'Basics', 'M1-A3 Variables, Expressions, and Types.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M01 - Basics', 'Basics', 'M1-A4 Print and Input.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M01 - Basics', 'Key M01 - Basics', 'KEY M1-A3 Hello World.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M01 - Basics', 'Key M01 - Basics', 'KEY M1-A4 Variables, Expressions, and Types (A).ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M01 - Basics', 'Key M01 - Basics', 'KEY M1-A4 Variables, Expressions, and Types (B).ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M01 - Basics', 'Key M01 - Basics', 'KEY M1-A5 Print and Input.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M02 - Lists Tuples Sets', '.ipynb_checkpoints', 'M02-A1 List Exercises-checkpoint.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M02 - Lists Tuples Sets', '.ipynb_checkpoints', 'M02-A2 Lists, Tuples, and Sets - Sorting Names in Arrays-checkpoint.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M02 - Lists Tuples Sets', '.ipynb_checkpoints', 'OLD M7-A1 Lists, Tuples, and Sets - 8 Word Index-checkpoint.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M02 - Lists Tuples Sets', 'Key M02-Lists tuples sets', '.ipynb_checkpoints', 'KEY M02-A1 List Exercises-checkpoint.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M02 - Lists Tuples Sets', 'Key M02-Lists tuples sets', 'KEY M02-A1 List Exercises.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M02 - Lists Tuples Sets', 'Key M02-Lists tuples sets', 'KEY M02-A2 Lists, Tuples, and Sets - Sorting Names in Arrays.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M02 - Lists Tuples Sets', 'Key M02-Lists tuples sets', 'OLD KEY M02-A1 Lists, Tuples, and Sets - 8 Word Index.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M02 - Lists Tuples Sets', 'M02-A1 List Exercises.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M02 - Lists Tuples Sets', 'M02-A2 Lists, Tuples, and Sets - Sorting Names in Arrays.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M02 - Lists Tuples Sets', 'OLD M7-A1 Lists, Tuples, and Sets - 8 Word Index.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M03 - Modules and Environments', 'M03-A1 Working with Anaconda Environments(1).ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M03 - Modules and Environments', 'M03-A1 Working with Anaconda Environments.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M04 - Flow Control - Loops and conditionals', 'Key M04 - Flow control - Looping', 'KEY M04-A1 Flow Control - Umbrella.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M04 - Flow Control - Loops and conditionals', 'Key M04 - Flow control - Looping', 'KEY M04-A2 Flow Control - Days of the Week.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M04 - Flow Control - Loops and conditionals', 'Key M04 - Flow control - Looping', 'KEY M04-A3 Flow Control - Number Patterns.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M04 - Flow Control - Loops and conditionals', 'Key M04 - Flow control - Looping', 'KEY M04-B1 Loops - Fizz Buzz.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M04 - Flow Control - Loops and conditionals', 'Key M04 - Flow control - Looping', 'OLDKEY M2-B2 Loops - Diamond.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M04 - Flow Control - Loops and conditionals', 'M04-A1 Flow Control - Umbrella.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M04 - Flow Control - Loops and conditionals', 'M04-A2 Flow Control - Days of the Week.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M04 - Flow Control - Loops and conditionals', 'M04-A3 Flow Control - Number Patterns.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M04 - Flow Control - Loops and conditionals', 'M04-B1 Loops - Fizz Buzz.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M04 - Flow Control - Loops and conditionals', 'OLDM02-B2 Loops - Diamond.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M05 - Functions', 'Key M04 - Functions', 'KEY M4-A1 Functions Practice .ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M05 - Functions', 'Key M04 - Functions', 'KEY M4-A2 Functions - Rock Paper Scissors.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M05 - Functions', 'Key M04 - Functions', 'M4-A2 Functions Practice.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M05 - Functions', 'M04-A2 Functions - Rock Paper Scissors.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M05 - Functions', 'M04-A2 Functions Practice.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M06 - Manipulating Strings', 'Key M06 - Strings', 'KEY M6-A1 Manipulating Strings - First Name Last Name.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M06 - Manipulating Strings', 'Key M06 - Strings', 'KEY M6-A1 Manipulating Strings.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M06 - Manipulating Strings', 'Key M06 - Strings', 'KEY M6-A3 Manipulating Strings - Name and Birth Year.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M06 - Manipulating Strings', 'M06-A1 Manipulating Strings.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M06 - Manipulating Strings', 'M6-A1 Manipulating Strings - First Name Last Name.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M06 - Manipulating Strings', 'M6-A2 Strings - Addresses.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M06 - Manipulating Strings', 'M6-A3 Manipulating Strings - Name and Birth Year.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M07 - File operations', 'Key M05 - File operations', 'KEY M5-A1 File operations practice.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M07 - File operations', 'Key M05 - File operations', 'M5-A1 File operations practice-Copy1.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M07 - File operations', 'Key M05 - File operations', 'M5-A1 File operations practice.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M07 - File operations', 'M05-A1 File operations practice.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M08 - Dictionaries', '.ipynb_checkpoints', 'M8-A1 Using Dictionaries-checkpoint.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M08 - Dictionaries', '.ipynb_checkpoints', 'M8-A2 Grocery List-checkpoint.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M08 - Dictionaries', '.ipynb_checkpoints', 'MIS501 Football part 1-checkpoint.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M08 - Dictionaries', 'KEY MIS501 Football part 1.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M08 - Dictionaries', 'Key M08 - Dictionaries', 'KEY M8-A1 Using Dictionaries.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M08 - Dictionaries', 'Key M08 - Dictionaries', 'KEY M8-A2 Grocery List.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M08 - Dictionaries', 'Key M08 - Dictionaries', 'M8-A1 Using Dictionaries key.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M08 - Dictionaries', 'M8-A1 Using Dictionaries.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M08 - Dictionaries', 'M8-A2 Grocery List.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M08 - Dictionaries', 'MIS501 Football part 1.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M09 - Error handling', 'Key M09 - Error handling', 'KEY M9-A1 Error Handling.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M09 - Error handling', 'M09-A1 Error Handling (1).ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M10 - Regex', 'Key M10 - Regex', 'KEY M10-A1 Regular Expressions - IP Addresses.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M10 - Regex', 'Key M10 - Regex', 'KEY M10-A2 Regular Expressions - Domain Names.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M10 - Regex', 'M10-A2 Regular Expressions - IP Addresses.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M10 - Regex', 'M10-A3 Regular Expressions - Domain Names.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M11 - Database', 'Key M11 - Database', 'key - M11-A1 Database practice.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M11 - Database', 'M11-A1 Database practice.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M11 - Database', 'OLDM11-A1 Database practice.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M12 - Web scraping', 'M12 Keys', 'KEY M12-A1 Webscraping HTML Elements.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M12 - Web scraping', 'M12 Keys', 'KEY M12-A2 Play 2084 (Rachel).ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M12 - Web scraping', 'M12 Keys', 'KEY M12-A2 Play 2084.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M12 - Web scraping', 'M12 Keys', 'M12 culverhouse.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M12 - Web scraping', 'M12 Keys', 'Untitled.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M12 - Web scraping', 'M12 Keys', 'indeed-class6-30.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M12 - Web scraping', 'M12 Keys', 'indeed-page-scraper.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M12 - Web scraping', 'M12 Keys', 'indeed-tutorial.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M12 - Web scraping', 'M12 Keys', 'scratch-bs4.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M12 - Web scraping', 'M12-A1 Webscraping HTML Elements.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M12 - Web scraping', 'M12-A2 Play 2048.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M12 - Web scraping', 'M12-A3 - Selenium 2048', 'Key M12-A3 - Selenium 2048', 'Key M12-A3 Play2084-key.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M12 - Web scraping', 'M12-A3 - Selenium 2048', 'Key M12-A3 - Selenium 2048', 'Play2084-answer.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M12 - Web scraping', 'M12-A3 - Selenium 2048', 'Key M12-A3 - Selenium 2048', 'Play2084-assignment.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M12 - Web scraping', 'Part1_Web_API_Requests.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M12 - Web scraping', 'Part2_HTML_Parsing_BeautifulSoup.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M12 - Web scraping', 'Play2084-assignment.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M12 - Web scraping', 'Untitled.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M13 - Numpy', 'M13-A1 Numpy basics.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M13 - Numpy', 'M13-A2 Seattle Rain.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'M14 - Pandas', 'M14-A1 Seattle Rain.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'Problem Set', 'Keys', 'NKF_Play.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'Problem Set', 'Keys', 'OLD_PS2-B IA Liquor key.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'Problem Set', 'Keys', 'PS1-A IA Liquor intro key.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'Problem Set', 'Keys', 'PS1-Part 2 IA Liquor key.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'Problem Set', 'Keys', 'Slope_Detection.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'Problem Set', 'PS1-A IA Liquor intro.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'Problem Set', 'PS1-Part 2-2019 IA Liqour.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'Set v Tuple v List.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'assignments', 'fitting dists.ipynb')
#    + ('Insync', 'gjbott@ua.edu', 'OneDrive Biz', 'teaching', 'MIS 501', '501_ta_shared', 'b_Using Jupyter Lab.ipynb')
#    + ('Untitled.ipynb',)
#    + ('Untitled1.ipynb',)
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'matplotlib', 'backends', 'web_backend', 'nbagg_uat.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbclassic', 'bundler', 'tests', 'resources', 'empty.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Autokill.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Check History in Memory.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Clear Output.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Disable Stdin.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Empty Cell.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Error.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Factorials.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'HelloWorld.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Inline Image.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Interrupt.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'JupyterWidgets.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Other Comms.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Output.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Parallel Execute A.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Parallel Execute B.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'SVG.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Skip Exceptions with Cell Tags.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Skip Exceptions.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Skip Execution with Cell Tag.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Sleep1s.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Unicode.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'UnicodePy3.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'update-display-id.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'exporters', 'tests', 'files', 'attachment.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'exporters', 'tests', 'files', 'notebook2.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'exporters', 'tests', 'files', 'notebook3.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'exporters', 'tests', 'files', 'notebook_inject.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'exporters', 'tests', 'files', 'pngmetadata.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'exporters', 'tests', 'files', 'prompt_numbers.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'exporters', 'tests', 'files', 'rawtest.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'exporters', 'tests', 'files', 'svg.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'preprocessors', 'tests', 'files', 'HelloWorld.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'preprocessors', 'tests', 'files', 'MixedMarkdown.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'tests', 'files', 'Unexecuted_widget.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'tests', 'files', 'Unexecuted_widget_2.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'tests', 'files', 'Widget_List.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'tests', 'files', 'latex-linked-image.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'tests', 'files', 'markdown_display_priority.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'tests', 'files', 'notebook1.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'tests', 'files', 'notebook2.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'tests', 'files', 'notebook3_with_errors.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'tests', 'files', 'notebook4_jpeg.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'tests', 'files', 'notebook5_embed_images.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'tests', 'files', 'notebook_jl.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'tests', 'files', 'notebook_tags.ipynb')
#    + ('anaconda3', 'envs', 'ai', 'lib', 'python3.11', 'site-packages', 'notebook', 'bundler', 'tests', 'resources', 'empty.ipynb')
#    + ('anaconda3', 'envs', 'bott', 'lib', 'python3.11', 'site-packages', 'matplotlib', 'backends', 'web_backend', 'nbagg_uat.ipynb')
#    + ('anaconda3', 'envs', 'bott', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Autokill.ipynb')
#    + ('anaconda3', 'envs', 'bott', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Check History in Memory.ipynb')
#    + ('anaconda3', 'envs', 'bott', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Clear Output.ipynb')
#    + ('anaconda3', 'envs', 'bott', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Disable Stdin.ipynb')
#    + ('anaconda3', 'envs', 'bott', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Empty Cell.ipynb')
#    + ('anaconda3', 'envs', 'bott', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Error.ipynb')
#    + ('anaconda3', 'envs', 'bott', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Factorials.ipynb')
#    + ('anaconda3', 'envs', 'bott', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'HelloWorld.ipynb')
#    + ('anaconda3', 'envs', 'bott', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Inline Image.ipynb')
#    + ('anaconda3', 'envs', 'bott', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Interrupt.ipynb')
#    + ('anaconda3', 'envs', 'bott', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'JupyterWidgets.ipynb')
#    + ('anaconda3', 'envs', 'bott', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Other Comms.ipynb')
#    + ('anaconda3', 'envs', 'bott', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Output.ipynb')
#    + ('anaconda3', 'envs', 'bott', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Parallel Execute A.ipynb')
#    + ('anaconda3', 'envs', 'bott', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Parallel Execute B.ipynb')
#    + ('anaconda3', 'envs', 'bott', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'SVG.ipynb')
#    + ('anaconda3', 'envs', 'bott', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Skip Exceptions with Cell Tags.ipynb')
#    + ('anaconda3', 'envs', 'bott', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Skip Exceptions.ipynb')
#    + ('anaconda3', 'envs', 'bott', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Skip Execution with Cell Tag.ipynb')
#    + ('anaconda3', 'envs', 'bott', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Sleep1s.ipynb')
#    + ('anaconda3', 'envs', 'bott', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'Unicode.ipynb')
#    + ('anaconda3', 'envs', 'bott', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'UnicodePy3.ipynb')
#    + ('anaconda3', 'envs', 'bott', 'lib', 'python3.11', 'site-packages', 'nbclient', 'tests', 'files', 'update-display-id.ipynb')
#    + ('anaconda3', 'envs', 'mis501', 'lib', 'python3.12', 'site-packages', 'matplotlib', 'backends', 'web_backend', 'nbagg_uat.ipynb')
#    + ('anaconda3', 'envs', 'mis501', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Autokill.ipynb')
#    + ('anaconda3', 'envs', 'mis501', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Check History in Memory.ipynb')
#    + ('anaconda3', 'envs', 'mis501', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Clear Output.ipynb')
#    + ('anaconda3', 'envs', 'mis501', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Disable Stdin.ipynb')
#    + ('anaconda3', 'envs', 'mis501', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Empty Cell.ipynb')
#    + ('anaconda3', 'envs', 'mis501', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Error.ipynb')
#    + ('anaconda3', 'envs', 'mis501', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Factorials.ipynb')
#    + ('anaconda3', 'envs', 'mis501', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'HelloWorld.ipynb')
#    + ('anaconda3', 'envs', 'mis501', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Inline Image.ipynb')
#    + ('anaconda3', 'envs', 'mis501', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Interrupt.ipynb')
#    + ('anaconda3', 'envs', 'mis501', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'JupyterWidgets.ipynb')
#    + ('anaconda3', 'envs', 'mis501', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Other Comms.ipynb')
#    + ('anaconda3', 'envs', 'mis501', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Output.ipynb')
#    + ('anaconda3', 'envs', 'mis501', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Parallel Execute A.ipynb')
#    + ('anaconda3', 'envs', 'mis501', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Parallel Execute B.ipynb')
#    + ('anaconda3', 'envs', 'mis501', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'SVG.ipynb')
#    + ('anaconda3', 'envs', 'mis501', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Skip Exceptions with Cell Tags.ipynb')
#    + ('anaconda3', 'envs', 'mis501', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Skip Exceptions.ipynb')
#    + ('anaconda3', 'envs', 'mis501', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Skip Execution with Cell Tag.ipynb')
#    + ('anaconda3', 'envs', 'mis501', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Sleep1s.ipynb')
#    + ('anaconda3', 'envs', 'mis501', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Unicode.ipynb')
#    + ('anaconda3', 'envs', 'mis501', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'UnicodePy3.ipynb')
#    + ('anaconda3', 'envs', 'mis501', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'update-display-id.ipynb')
#    + ('anaconda3', 'envs', 'scrape4', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Autokill.ipynb')
#    + ('anaconda3', 'envs', 'scrape4', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Check History in Memory.ipynb')
#    + ('anaconda3', 'envs', 'scrape4', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Clear Output.ipynb')
#    + ('anaconda3', 'envs', 'scrape4', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Disable Stdin.ipynb')
#    + ('anaconda3', 'envs', 'scrape4', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Empty Cell.ipynb')
#    + ('anaconda3', 'envs', 'scrape4', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Error.ipynb')
#    + ('anaconda3', 'envs', 'scrape4', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Factorials.ipynb')
#    + ('anaconda3', 'envs', 'scrape4', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'HelloWorld.ipynb')
#    + ('anaconda3', 'envs', 'scrape4', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Inline Image.ipynb')
#    + ('anaconda3', 'envs', 'scrape4', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Interrupt.ipynb')
#    + ('anaconda3', 'envs', 'scrape4', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'JupyterWidgets.ipynb')
#    + ('anaconda3', 'envs', 'scrape4', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Other Comms.ipynb')
#    + ('anaconda3', 'envs', 'scrape4', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Output.ipynb')
#    + ('anaconda3', 'envs', 'scrape4', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Parallel Execute A.ipynb')
#    + ('anaconda3', 'envs', 'scrape4', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Parallel Execute B.ipynb')
#    + ('anaconda3', 'envs', 'scrape4', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'SVG.ipynb')
#    + ('anaconda3', 'envs', 'scrape4', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Skip Exceptions with Cell Tags.ipynb')
#    + ('anaconda3', 'envs', 'scrape4', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Skip Exceptions.ipynb')
#    + ('anaconda3', 'envs', 'scrape4', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Skip Execution with Cell Tag.ipynb')
#    + ('anaconda3', 'envs', 'scrape4', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Sleep1s.ipynb')
#    + ('anaconda3', 'envs', 'scrape4', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'Unicode.ipynb')
#    + ('anaconda3', 'envs', 'scrape4', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'UnicodePy3.ipynb')
#    + ('anaconda3', 'envs', 'scrape4', 'lib', 'python3.12', 'site-packages', 'nbclient', 'tests', 'files', 'update-display-id.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'colorcet', 'examples', 'index.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'colorcet', 'examples', 'user_guide', 'Categorical.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'colorcet', 'examples', 'user_guide', 'Continuous.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'colorcet', 'examples', 'user_guide', 'index.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'datashader', 'examples', 'FAQ.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'datashader', 'examples', 'getting_started', '1_Introduction.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'datashader', 'examples', 'getting_started', '2_Pipeline.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'datashader', 'examples', 'getting_started', '3_Interactivity.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'datashader', 'examples', 'getting_started', 'index.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'datashader', 'examples', 'index.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'datashader', 'examples', 'tiling.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'datashader', 'examples', 'user_guide', '10_Performance.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'datashader', 'examples', 'user_guide', '11_Geography.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'datashader', 'examples', 'user_guide', '12_Inspection_Reductions.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'datashader', 'examples', 'user_guide', '13_Geopandas.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'datashader', 'examples', 'user_guide', '1_Plotting_Pitfalls.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'datashader', 'examples', 'user_guide', '2_Points.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'datashader', 'examples', 'user_guide', '3_Timeseries.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'datashader', 'examples', 'user_guide', '4_Trajectories.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'datashader', 'examples', 'user_guide', '5_Grids.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'datashader', 'examples', 'user_guide', '6_Trimesh.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'datashader', 'examples', 'user_guide', '7_Networks.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'datashader', 'examples', 'user_guide', '8_Polygons.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'datashader', 'examples', 'user_guide', '9_Extending.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'area_chart.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'autompg_histogram.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'autompg_violins.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'bachelors_degrees_by_gender.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'bars_economic.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'box_draw_roi_editor.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'boxplot_chart.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'choropleth_data_link.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'directed_airline_routes.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'dot_example.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'dragon_curve.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'dropdown_economic.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'eeg_viewer.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'emoji_tsne.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'energy_sankey.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'hextile_movie_ratings.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'histogram_example.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'image_range_tool.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'iris_density_grid.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'iris_example.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'iris_grouped_grid.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'iris_splom_example.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'irregular_quadmesh.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'legend_example.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'lesmis_example.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'life_expectancy_split_violin.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'lorenz_attractor_example.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'mandelbrot_section.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'measles_example.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'network_graph.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'nyc_airport_connections.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'nyc_radial_heatmap.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'point_draw_triangulate.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'quiver_demo.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'route_chord.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'scatter_economic.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'square_limit.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'step_chart.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'stocks_example.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'texas_choropleth_example.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'timeseries_range_tool.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'topographic_hillshading.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'us_unemployment.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'bokeh', 'verhulst_mandelbrot.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'area_chart.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'autompg_histogram.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'autompg_violins.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'bachelors_degrees_by_gender.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'bars_economic.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'boxplot_chart.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'directed_airline_routes.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'dragon_curve.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'dropdown_economic.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'energy_sankey.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'hextile_movie_ratings.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'histogram_example.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'iris_density_grid.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'iris_example.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'iris_grouped_grid.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'iris_splom_example.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'irregular_quadmesh.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'legend_example.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'lorenz_attractor_example.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'mandelbrot_section.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'measles_example.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'network_graph.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'nyc_airport_connections.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'nyc_radial_heatmap.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'polar_scatter_demo.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'quiver_demo.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'route_chord.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'scatter_economic.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'square_limit.ipynb')
#    + ('anaconda3', 'lib', 'python3.11', 'site-packages', 'holoviews', 'examples', 'gallery', 'demos', 'matplotlib', 'step_chart.ipynb')
# ...
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py311h06a4308_0', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'exporters', 'tests', 'files', 'prompt_numbers.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py311h06a4308_0', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'exporters', 'tests', 'files', 'rawtest.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py311h06a4308_0', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'exporters', 'tests', 'files', 'svg.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py311h06a4308_0', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'preprocessors', 'tests', 'files', 'HelloWorld.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py311h06a4308_0', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'preprocessors', 'tests', 'files', 'MixedMarkdown.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py311h06a4308_0', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'tests', 'files', 'Unexecuted_widget.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py311h06a4308_0', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'tests', 'files', 'Unexecuted_widget_2.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py311h06a4308_0', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'tests', 'files', 'Widget_List.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py311h06a4308_0', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'tests', 'files', 'latex-linked-image.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py311h06a4308_0', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'tests', 'files', 'markdown_display_priority.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py311h06a4308_0', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'tests', 'files', 'notebook1.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py311h06a4308_0', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'tests', 'files', 'notebook2.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py311h06a4308_0', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'tests', 'files', 'notebook3_with_errors.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py311h06a4308_0', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'tests', 'files', 'notebook4_jpeg.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py311h06a4308_0', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'tests', 'files', 'notebook5_embed_images.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py311h06a4308_0', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'tests', 'files', 'notebook_jl.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py311h06a4308_0', 'lib', 'python3.11', 'site-packages', 'nbconvert', 'tests', 'files', 'notebook_tags.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py37h06a4308_0', 'info', 'test', 'nbconvert', 'tests', 'files', 'notebook1.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py37h06a4308_0', 'lib', 'python3.7', 'site-packages', 'nbconvert', 'exporters', 'tests', 'files', 'attachment.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py37h06a4308_0', 'lib', 'python3.7', 'site-packages', 'nbconvert', 'exporters', 'tests', 'files', 'notebook2.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py37h06a4308_0', 'lib', 'python3.7', 'site-packages', 'nbconvert', 'exporters', 'tests', 'files', 'notebook3.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py37h06a4308_0', 'lib', 'python3.7', 'site-packages', 'nbconvert', 'exporters', 'tests', 'files', 'notebook_inject.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py37h06a4308_0', 'lib', 'python3.7', 'site-packages', 'nbconvert', 'exporters', 'tests', 'files', 'pngmetadata.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py37h06a4308_0', 'lib', 'python3.7', 'site-packages', 'nbconvert', 'exporters', 'tests', 'files', 'prompt_numbers.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py37h06a4308_0', 'lib', 'python3.7', 'site-packages', 'nbconvert', 'exporters', 'tests', 'files', 'rawtest.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py37h06a4308_0', 'lib', 'python3.7', 'site-packages', 'nbconvert', 'exporters', 'tests', 'files', 'svg.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py37h06a4308_0', 'lib', 'python3.7', 'site-packages', 'nbconvert', 'preprocessors', 'tests', 'files', 'HelloWorld.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py37h06a4308_0', 'lib', 'python3.7', 'site-packages', 'nbconvert', 'preprocessors', 'tests', 'files', 'MixedMarkdown.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py37h06a4308_0', 'lib', 'python3.7', 'site-packages', 'nbconvert', 'tests', 'files', 'Unexecuted_widget.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py37h06a4308_0', 'lib', 'python3.7', 'site-packages', 'nbconvert', 'tests', 'files', 'Unexecuted_widget_2.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py37h06a4308_0', 'lib', 'python3.7', 'site-packages', 'nbconvert', 'tests', 'files', 'Widget_List.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py37h06a4308_0', 'lib', 'python3.7', 'site-packages', 'nbconvert', 'tests', 'files', 'latex-linked-image.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py37h06a4308_0', 'lib', 'python3.7', 'site-packages', 'nbconvert', 'tests', 'files', 'markdown_display_priority.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py37h06a4308_0', 'lib', 'python3.7', 'site-packages', 'nbconvert', 'tests', 'files', 'notebook1.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py37h06a4308_0', 'lib', 'python3.7', 'site-packages', 'nbconvert', 'tests', 'files', 'notebook2.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py37h06a4308_0', 'lib', 'python3.7', 'site-packages', 'nbconvert', 'tests', 'files', 'notebook3_with_errors.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py37h06a4308_0', 'lib', 'python3.7', 'site-packages', 'nbconvert', 'tests', 'files', 'notebook4_jpeg.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py37h06a4308_0', 'lib', 'python3.7', 'site-packages', 'nbconvert', 'tests', 'files', 'notebook5_embed_images.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py37h06a4308_0', 'lib', 'python3.7', 'site-packages', 'nbconvert', 'tests', 'files', 'notebook_jl.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-6.5.4-py37h06a4308_0', 'lib', 'python3.7', 'site-packages', 'nbconvert', 'tests', 'files', 'notebook_tags.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-7.10.0-py311h06a4308_0', 'info', 'test', 'tests', 'exporters', 'files', 'attachment.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-7.10.0-py311h06a4308_0', 'info', 'test', 'tests', 'exporters', 'files', 'notebook2.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-7.10.0-py311h06a4308_0', 'info', 'test', 'tests', 'exporters', 'files', 'notebook3.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-7.10.0-py311h06a4308_0', 'info', 'test', 'tests', 'exporters', 'files', 'notebook_inject.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-7.10.0-py311h06a4308_0', 'info', 'test', 'tests', 'exporters', 'files', 'pngmetadata.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-7.10.0-py311h06a4308_0', 'info', 'test', 'tests', 'exporters', 'files', 'prompt_numbers.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-7.10.0-py311h06a4308_0', 'info', 'test', 'tests', 'exporters', 'files', 'rawtest.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-7.10.0-py311h06a4308_0', 'info', 'test', 'tests', 'exporters', 'files', 'svg.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-7.10.0-py311h06a4308_0', 'info', 'test', 'tests', 'files', 'Unexecuted_widget.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-7.10.0-py311h06a4308_0', 'info', 'test', 'tests', 'files', 'Unexecuted_widget_2.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-7.10.0-py311h06a4308_0', 'info', 'test', 'tests', 'files', 'Widget_List.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-7.10.0-py311h06a4308_0', 'info', 'test', 'tests', 'files', 'latex-linked-image.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-7.10.0-py311h06a4308_0', 'info', 'test', 'tests', 'files', 'markdown_display_priority.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-7.10.0-py311h06a4308_0', 'info', 'test', 'tests', 'files', 'notebook1.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-7.10.0-py311h06a4308_0', 'info', 'test', 'tests', 'files', 'notebook2.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-7.10.0-py311h06a4308_0', 'info', 'test', 'tests', 'files', 'notebook3_with_errors.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-7.10.0-py311h06a4308_0', 'info', 'test', 'tests', 'files', 'notebook4_jpeg.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-7.10.0-py311h06a4308_0', 'info', 'test', 'tests', 'files', 'notebook5_embed_images.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-7.10.0-py311h06a4308_0', 'info', 'test', 'tests', 'files', 'notebook_jl.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-7.10.0-py311h06a4308_0', 'info', 'test', 'tests', 'files', 'notebook_tags.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-7.10.0-py311h06a4308_0', 'info', 'test', 'tests', 'preprocessors', 'files', 'HelloWorld.ipynb')
#    + ('anaconda3', 'pkgs', 'nbconvert-7.10.0-py311h06a4308_0', 'info', 'test', 'tests', 'preprocessors', 'files', 'MixedMarkdown.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.7.0-py37h06a4308_0', 'info', 'test', 'tests', 'invalid.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.7.0-py37h06a4308_0', 'info', 'test', 'tests', 'invalid_cell_id.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.7.0-py37h06a4308_0', 'info', 'test', 'tests', 'invalid_unique_cell_id.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.7.0-py37h06a4308_0', 'info', 'test', 'tests', 'many_tracebacks.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.7.0-py37h06a4308_0', 'info', 'test', 'tests', 'no_min_version.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.7.0-py37h06a4308_0', 'info', 'test', 'tests', 'test2.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.7.0-py37h06a4308_0', 'info', 'test', 'tests', 'test3.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.7.0-py37h06a4308_0', 'info', 'test', 'tests', 'test3_no_metadata.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.7.0-py37h06a4308_0', 'info', 'test', 'tests', 'test3_no_worksheets.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.7.0-py37h06a4308_0', 'info', 'test', 'tests', 'test3_worksheet_with_no_cells.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.7.0-py37h06a4308_0', 'info', 'test', 'tests', 'test4.5.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.7.0-py37h06a4308_0', 'info', 'test', 'tests', 'test4.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.7.0-py37h06a4308_0', 'info', 'test', 'tests', 'test4custom.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.7.0-py37h06a4308_0', 'info', 'test', 'tests', 'test4docinfo.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.7.0-py37h06a4308_0', 'info', 'test', 'tests', 'test4jupyter_metadata.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.7.0-py37h06a4308_0', 'info', 'test', 'tests', 'test4jupyter_metadata_timings.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.7.0-py37h06a4308_0', 'info', 'test', 'tests', 'test4plus.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.7.0-py37h06a4308_0', 'info', 'test', 'tests', 'v4_5_invalid_metadata.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.7.0-py37h06a4308_0', 'info', 'test', 'tests', 'v4_5_no_cell_id.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-py311h06a4308_0', 'info', 'test', 'tests', 'invalid.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-py311h06a4308_0', 'info', 'test', 'tests', 'invalid_cell_id.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-py311h06a4308_0', 'info', 'test', 'tests', 'invalid_unique_cell_id.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-py311h06a4308_0', 'info', 'test', 'tests', 'many_tracebacks.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-py311h06a4308_0', 'info', 'test', 'tests', 'no_min_version.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-py311h06a4308_0', 'info', 'test', 'tests', 'test2.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-py311h06a4308_0', 'info', 'test', 'tests', 'test3.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-py311h06a4308_0', 'info', 'test', 'tests', 'test3_no_metadata.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-py311h06a4308_0', 'info', 'test', 'tests', 'test3_no_min_version.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-py311h06a4308_0', 'info', 'test', 'tests', 'test3_no_worksheets.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-py311h06a4308_0', 'info', 'test', 'tests', 'test3_worksheet_with_no_cells.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-py311h06a4308_0', 'info', 'test', 'tests', 'test4.5.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-py311h06a4308_0', 'info', 'test', 'tests', 'test4.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-py311h06a4308_0', 'info', 'test', 'tests', 'test4custom.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-py311h06a4308_0', 'info', 'test', 'tests', 'test4docinfo.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-py311h06a4308_0', 'info', 'test', 'tests', 'test4jupyter_metadata.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-py311h06a4308_0', 'info', 'test', 'tests', 'test4jupyter_metadata_timings.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-py311h06a4308_0', 'info', 'test', 'tests', 'test4plus.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-py311h06a4308_0', 'info', 'test', 'tests', 'v4_5_invalid_metadata.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-py311h06a4308_0', 'info', 'test', 'tests', 'v4_5_no_cell_id.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-pyhd8ed1ab_0', 'info', 'test', 'tests', 'invalid.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-pyhd8ed1ab_0', 'info', 'test', 'tests', 'invalid_cell_id.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-pyhd8ed1ab_0', 'info', 'test', 'tests', 'invalid_unique_cell_id.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-pyhd8ed1ab_0', 'info', 'test', 'tests', 'many_tracebacks.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-pyhd8ed1ab_0', 'info', 'test', 'tests', 'no_min_version.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-pyhd8ed1ab_0', 'info', 'test', 'tests', 'test2.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-pyhd8ed1ab_0', 'info', 'test', 'tests', 'test3.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-pyhd8ed1ab_0', 'info', 'test', 'tests', 'test3_no_metadata.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-pyhd8ed1ab_0', 'info', 'test', 'tests', 'test3_no_min_version.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-pyhd8ed1ab_0', 'info', 'test', 'tests', 'test3_no_worksheets.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-pyhd8ed1ab_0', 'info', 'test', 'tests', 'test3_worksheet_with_no_cells.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-pyhd8ed1ab_0', 'info', 'test', 'tests', 'test4.5.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-pyhd8ed1ab_0', 'info', 'test', 'tests', 'test4.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-pyhd8ed1ab_0', 'info', 'test', 'tests', 'test4custom.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-pyhd8ed1ab_0', 'info', 'test', 'tests', 'test4docinfo.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-pyhd8ed1ab_0', 'info', 'test', 'tests', 'test4jupyter_metadata.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-pyhd8ed1ab_0', 'info', 'test', 'tests', 'test4jupyter_metadata_timings.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-pyhd8ed1ab_0', 'info', 'test', 'tests', 'test4plus.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-pyhd8ed1ab_0', 'info', 'test', 'tests', 'v4_5_invalid_metadata.ipynb')
#    + ('anaconda3', 'pkgs', 'nbformat-5.9.2-pyhd8ed1ab_0', 'info', 'test', 'tests', 'v4_5_no_cell_id.ipynb')
#    + ('anaconda3', 'pkgs', 'notebook-6.5.2-py37h06a4308_0', 'lib', 'python3.7', 'site-packages', 'notebook', 'bundler', 'tests', 'resources', 'empty.ipynb')
#    + ('anaconda3', 'pkgs', 'notebook-6.5.4-py311h06a4308_1', 'lib', 'python3.11', 'site-packages', 'notebook', 'bundler', 'tests', 'resources', 'empty.ipynb')
#    + ('birthday_attack.ipynb',)

# %% [markdown]
# ## Checking if Path exists and creating a folder

# %% [markdown]
# ```Python
# parents = True
# ```
# creates all folders in the path as needed.
#
# ```Python
# exist_ok = False
# ```
# by default, raises FileExistsError if the target directory already exists.

# %%
all_py_files = pathlib.Path.home().rglob('*.py')

# %%
all_py_files = [file.name for file in all_py_files]

# %%
len(all_py_files)
# Out:
# 156428

# %%
all_py_files[:50]
# Out:
# ['scrape_module.py',
#  'get_pytest_options.py',
#  'check_tk_compat.py',
#  'check_protocols.py',
#  'check_task.py',
#  'check_post.py',
#  'check_relativedelta.py',
#  'check_base_descriptors.py',
#  'check_finditer.py',
#  'check_struct.py',
#  'update_ext_version.py',
#  'test_update_ext_version.py',
#  '__init__.py',
#  'lsp_runner.py',
#  'lsp_jsonrpc.py',
#  'lsp_utils.py',
#  'lsp_server.py',
#  'typing_extensions.py',
#  'pycodestyle.py',
#  'mccabe.py',
#  '__init__.py',
#  'exceptions.py',
#  'client.py',
#  'feature_manager.py',
#  'progress.py',
#  'constants.py',
#  'server.py',
#  'uris.py',
#  'capabilities.py',
#  '__init__.py',
#  '_py39compat.py',
#  '_functools.py',
#  '_compat.py',
#  '_text.py',
#  '_collections.py',
#  '_adapters.py',
#  '_meta.py',
#  '_itertools.py',
#  '__init__.py',
#  'checker.py',
#  'reporter.py',
#  'api.py',
#  'messages.py',
#  '__main__.py',
#  '__init__.py',
#  'errors.py',
#  'disambiguators.py',
#  'gen.py',
#  'dispatch.py',
#  'converters.py']

# %%
# This can be accomplished in a single line
pathlib.Path.cwd().joinpath('HW102').mkdir(parents=True, exist_ok=True)

# %%
if pathlib.Path.cwd().joinpath('HW101').exists():
    hw_path = pathlib.Path.cwd().joinpath('HW101').exists()
else:
    pathlib.Path.cwd().joinpath('HW101').mkdir()

# %%
# Another way to create a path
folder_name = "HW101"
hw_path = pathlib.Path.cwd().joinpath(folder_name).exists()
try:
    pathlib.Path.cwd().joinpath(folder_name).mkdir()
except FileExistsError:
    print(f'{folder_name} exists.')
else:
    print(f'{folder_name} created.')
# Out:
# HW101 exists.

# %% [markdown]
# ### Check if file or folder exists

# %%
# Build a path
doc_path = pathlib.Path.home() / 'Documents' / 'MIS501'
doc_path.exists()
# Out:
# False

# %%
# ERROR: Why does the following line throw an exception?
# How could you fix it?
win_users = 'C:\Users'
# Out:
#   Input In [13]
#     win_users = 'C:\Users'
#                           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %% [markdown]
# ## Reading files
# There are several ways to read data from a file. Some of the methods to read a file include: reading a specified number of characters, reading line-by-line, or a reading number of lines.

# %% [markdown]
# ### Reading an entire file

# %%
import pathlib

# %%
file_path = pathlib.Path('files/gettysburg.txt')
with open(file_path,"r") as fh_getty:
    #read() will access the entire file. Not a good option for large files.
    print(fh_getty.read())

# %%
with open(file_path,"r") as fh_getty:
    n = 100
    #read() will access the entire file. Not a good option for large files.
    print(fh_getty.read(n)) # Read the first n characters

# %%
with open(file_path,"r") as fh_getty:    
    #read() will access the entire file. Not a good option for large files.
    print(fh_getty.readline()) # Read a line
    print(fh_getty.readline()) # Read a line
    print(fh_getty.readline()) # Read a line

# %%
with open(file_path,"r") as fh_getty:    
    #read() will access the entire file. Not a good option for large files.
    x = fh_getty.readlines() # Read all lines with new line characters, separated by commas
    print(x[5])

# %%
with open(file_path,"r") as fh_getty:
    line_number = 0
    for x in fh_getty: # "x" will represent a line
        print(str(line_number) + ": " + x)
        line_number += 1

# %%
customer_file = pathlib.Path(r'files/fake_customer_list.txt')
with open(customer_file, 'r') as fh_customers:

    for line in fh_customers:
        #print(line)
        customer_list = line.strip().split("|")
        full_name = customer_list[0]
        email = customer_list[-1]
        print(full_name + " -- " + email)

# %%
# List files in the current directory 
import os
import pprint as pp # 'pretty prints' the output in a column
pp.pprint(os.listdir(os.getcwd()))

# %%
# 'Magic' command to list files in current directory
# %ls

# %% [markdown]
# ### Use the CSV module to read a file

# %%
import csv
with open('./files/lyricsonly2M.csv', 'r') as f:
    reader = csv.reader(f)
    your_list = list(reader)

# %%
pp.pprint(your_list[:99])

# %%
len(your_list)

# %%
import pandas as pd
df_lyrics = pd.DataFrame(your_list, columns=your_list[0])

# %%
print(df_lyrics.shape)
with pd.option_context('display.max_seq_items', None):
    print(df_lyrics.head(5000))

# %%
print(your_list[0])

# %% [markdown]
# ## Writing to a File

# %% [markdown]
# ## Use Pandas to Read a file
# Although built-in file operations in Python may be useful for trivial matters, Pandas and Numpy are much more effective for reading, shaping, and analyzing data. Using these libraries is beyond the scope of this course, however, you should be aware of these libraries. See the Pandas notebook for more information.

# %%
import pathlib

# %%
import pandas as pd
file_path = pathlib.Path('files/2017_instacart_products.csv')
df = pd.read_csv(file_path)
df.head()

# %%
# Use the describe function to display descriptive statistics for numerical fields (even if that doesn't make sense...)
df.describe()
